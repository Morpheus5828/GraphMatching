# %%
"""This module contains tool to display graph saved with .gpickle format
    After runing script_generation_graphs_with_edges_permutation.py, you can easily try visualisation 
    with a graph into graph_generated folder

..moduleauthor::Marius Thorre
"""

# %%
import graph_matching.utils.graph.display_graph_tools as display

# %%
graph = display.get_graph_from_pickle("graph_generated/0/reference_0.gpickle")

# %%
window = display.Visualisation(graph, title="Graph reference 0")
window.display()
